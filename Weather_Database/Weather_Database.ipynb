# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time

# %%
lats=np.random.uniform(-90,90,size=2000)
lngs=np.random.uniform(-180,180,size=2000)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
coordinates=list(lat_lngs)

# %%
cities=[]
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 765

# %%
#perform
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description=city_weather['weather'][0]['description']
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | ribeira grande
# Processing Record 3 of Set 1 | vardo
# Processing Record 4 of Set 1 | qasigiannguit
# Processing Record 5 of Set 1 | ossora
# Processing Record 6 of Set 1 | bereda
# Processing Record 7 of Set 1 | sur
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 1 | porto novo
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | pevek
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | carnarvon
# Processing Record 15 of Set 1 | souillac
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | ystad
# Processing Record 20 of Set 1 | sorland
# Processing Record 21 of Set 1 | vanavara
# Processing Record 22 of Set 1 | mchinji
# Processing Record 23 of Set 1 | burica
# City not found. Skipping...
# Processing Record 24 of Set 1 | ghedi
# Processing Record 25 of Set 1 | moron
# Processing Record 26 of Set 1 | sabha
# Processing Record 27 of Set 1 | dores do indaia
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | itaituba
# Processing Record 30 of Set 1 | zirandaro
# Processing Record 31 of Set 1 | sao filipe
# Processing Record 32 of Set 1 | sioux lookout
# Processing Record 33 of Set 1 | sampit
# Processing Record 34 of Set 1 | dolinsk
# Processing Record 35 of Set 1 | mbandaka
# Processing Record 36 of Set 1 | maturin
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | sandnessjoen
# Processing Record 40 of Set 1 | srednekolymsk
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 1 | inuvik
# Processing Record 44 of Set 1 | kahului
# Processing Record 45 of Set 1 | wajid
# Processing Record 46 of Set 1 | katsuura
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | norman wells
# Processing Record 49 of Set 1 | mehamn
# Processing Record 50 of Set 1 | nanortalik
# Processing Record 1 of Set 2 | saint-philippe
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | kapit
# Processing Record 5 of Set 2 | shingu
# Processing Record 6 of Set 2 | tiksi
# Processing Record 7 of Set 2 | okha
# Processing Record 8 of Set 2 | ponta delgada
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | luderitz
# Processing Record 11 of Set 2 | caravelas
# Processing Record 12 of Set 2 | bere
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | hithadhoo
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | abilene
# Processing Record 17 of Set 2 | svetlaya
# Processing Record 18 of Set 2 | mar del plata
# Processing Record 19 of Set 2 | butaritari
# Processing Record 20 of Set 2 | kostek
# Processing Record 21 of Set 2 | zhanakorgan
# Processing Record 22 of Set 2 | aras
# Processing Record 23 of Set 2 | dvinskoy
# Processing Record 24 of Set 2 | kyaukse
# Processing Record 25 of Set 2 | panorama
# Processing Record 26 of Set 2 | bengkulu
# Processing Record 27 of Set 2 | hambantota
# Processing Record 28 of Set 2 | dikson
# Processing Record 29 of Set 2 | ponta do sol
# Processing Record 30 of Set 2 | taltal
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | salalah
# Processing Record 33 of Set 2 | peace river
# Processing Record 34 of Set 2 | santa vitoria do palmar
# Processing Record 35 of Set 2 | hoi an
# Processing Record 36 of Set 2 | muisne
# Processing Record 37 of Set 2 | karakol
# Processing Record 38 of Set 2 | port blair
# Processing Record 39 of Set 2 | maragogi
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 2 | marawi
# Processing Record 43 of Set 2 | mentok
# City not found. Skipping...
# Processing Record 44 of Set 2 | lompoc
# Processing Record 45 of Set 2 | virginia beach
# Processing Record 46 of Set 2 | kerman
# Processing Record 47 of Set 2 | severo-kurilsk
# Processing Record 48 of Set 2 | marsh harbour
# Processing Record 49 of Set 2 | port elizabeth
# Processing Record 50 of Set 2 | puerto ayora
# Processing Record 1 of Set 3 | flinders
# Processing Record 2 of Set 3 | east london
# Processing Record 3 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 4 of Set 3 | new norfolk
# Processing Record 5 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 3 | tasiilaq
# Processing Record 7 of Set 3 | voznesenye
# Processing Record 8 of Set 3 | brandon
# Processing Record 9 of Set 3 | albany
# Processing Record 10 of Set 3 | bluff
# Processing Record 11 of Set 3 | kaitangata
# Processing Record 12 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 13 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 3 | clarksdale
# Processing Record 15 of Set 3 | vaini
# Processing Record 16 of Set 3 | bali
# Processing Record 17 of Set 3 | antakya
# Processing Record 18 of Set 3 | panacan
# Processing Record 19 of Set 3 | nome
# Processing Record 20 of Set 3 | mount gambier
# Processing Record 21 of Set 3 | toora-khem
# Processing Record 22 of Set 3 | georgetown
# Processing Record 23 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 3 | esperance
# Processing Record 25 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 3 | cherskiy
# Processing Record 27 of Set 3 | paka
# Processing Record 28 of Set 3 | sitka
# Processing Record 29 of Set 3 | ballarat
# Processing Record 30 of Set 3 | lasa
# Processing Record 31 of Set 3 | yumen
# Processing Record 32 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 3 | mayumba
# Processing Record 35 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 3 | chokurdakh
# Processing Record 37 of Set 3 | zarate
# Processing Record 38 of Set 3 | port alfred
# Processing Record 39 of Set 3 | piojo
# Processing Record 40 of Set 3 | bonfim
# Processing Record 41 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 42 of Set 3 | vao
# Processing Record 43 of Set 3 | khor
# Processing Record 44 of Set 3 | ballina
# Processing Record 45 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 3 | campana
# Processing Record 47 of Set 3 | shache
# Processing Record 48 of Set 3 | banjar
# Processing Record 49 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 3 | ukiah
# Processing Record 1 of Set 4 | alofi
# Processing Record 2 of Set 4 | ugoofaaru
# Processing Record 3 of Set 4 | hermanus
# Processing Record 4 of Set 4 | viedma
# Processing Record 5 of Set 4 | khatanga
# Processing Record 6 of Set 4 | suclayin
# Processing Record 7 of Set 4 | vila velha
# Processing Record 8 of Set 4 | el reno
# Processing Record 9 of Set 4 | fortuna
# Processing Record 10 of Set 4 | ancud
# Processing Record 11 of Set 4 | bambous virieux
# Processing Record 12 of Set 4 | yarmouth
# Processing Record 13 of Set 4 | ekibastuz
# Processing Record 14 of Set 4 | lindsay
# Processing Record 15 of Set 4 | vicosa
# Processing Record 16 of Set 4 | longyearbyen
# Processing Record 17 of Set 4 | mount isa
# Processing Record 18 of Set 4 | port hardy
# Processing Record 19 of Set 4 | banda aceh
# Processing Record 20 of Set 4 | hami
# Processing Record 21 of Set 4 | grivenskaya
# Processing Record 22 of Set 4 | thompson
# Processing Record 23 of Set 4 | bandarbeyla
# Processing Record 24 of Set 4 | havoysund
# Processing Record 25 of Set 4 | qandala
# Processing Record 26 of Set 4 | bosaso
# Processing Record 27 of Set 4 | waipawa
# Processing Record 28 of Set 4 | kavaratti
# Processing Record 29 of Set 4 | ulaangom
# Processing Record 30 of Set 4 | victoria
# Processing Record 31 of Set 4 | cordoba
# Processing Record 32 of Set 4 | dawei
# Processing Record 33 of Set 4 | springbok
# Processing Record 34 of Set 4 | codrington
# Processing Record 35 of Set 4 | karimganj
# Processing Record 36 of Set 4 | ayios matthaios
# City not found. Skipping...
# Processing Record 37 of Set 4 | provideniya
# Processing Record 38 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 4 | taphan hin
# Processing Record 41 of Set 4 | saint-pierre
# Processing Record 42 of Set 4 | anantapur
# Processing Record 43 of Set 4 | tuatapere
# Processing Record 44 of Set 4 | ahipara
# Processing Record 45 of Set 4 | kimbe
# Processing Record 46 of Set 4 | mecca
# Processing Record 47 of Set 4 | huangzhai
# Processing Record 48 of Set 4 | shetpe
# Processing Record 49 of Set 4 | cerritos
# Processing Record 50 of Set 4 | aklavik
# Processing Record 1 of Set 5 | vincennes
# Processing Record 2 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 5 | mandan
# Processing Record 4 of Set 5 | bethel
# Processing Record 5 of Set 5 | cruz do espirito santo
# Processing Record 6 of Set 5 | cedar falls
# Processing Record 7 of Set 5 | gladstone
# Processing Record 8 of Set 5 | palana
# Processing Record 9 of Set 5 | shyryayeve
# Processing Record 10 of Set 5 | bowen
# Processing Record 11 of Set 5 | iralaya
# Processing Record 12 of Set 5 | tevaitoa
# Processing Record 13 of Set 5 | mahaicony
# City not found. Skipping...
# Processing Record 14 of Set 5 | haines junction
# Processing Record 15 of Set 5 | kropotkin
# Processing Record 16 of Set 5 | tilichiki
# Processing Record 17 of Set 5 | hammerfest
# Processing Record 18 of Set 5 | scarborough
# Processing Record 19 of Set 5 | manaure
# Processing Record 20 of Set 5 | kavieng
# Processing Record 21 of Set 5 | daru
# Processing Record 22 of Set 5 | hanko
# Processing Record 23 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 5 | mahebourg
# Processing Record 25 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 26 of Set 5 | vestmanna
# Processing Record 27 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 5 | pisco
# Processing Record 29 of Set 5 | oliva
# Processing Record 30 of Set 5 | lazaro cardenas
# Processing Record 31 of Set 5 | baghdad
# Processing Record 32 of Set 5 | guerrero negro
# Processing Record 33 of Set 5 | ostrovnoy
# Processing Record 34 of Set 5 | sao joao da barra
# Processing Record 35 of Set 5 | alugan
# Processing Record 36 of Set 5 | udachnyy
# Processing Record 37 of Set 5 | ixtapa
# Processing Record 38 of Set 5 | mayna
# Processing Record 39 of Set 5 | eyl
# Processing Record 40 of Set 5 | pedernales
# Processing Record 41 of Set 5 | gryazi
# Processing Record 42 of Set 5 | narsaq
# Processing Record 43 of Set 5 | ilulissat
# Processing Record 44 of Set 5 | kharovsk
# Processing Record 45 of Set 5 | samarai
# Processing Record 46 of Set 5 | la ronge
# Processing Record 47 of Set 5 | kamaishi
# Processing Record 48 of Set 5 | bodden town
# Processing Record 49 of Set 5 | loa janan
# Processing Record 50 of Set 5 | nantucket
# Processing Record 1 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 2 of Set 6 | aksu
# Processing Record 3 of Set 6 | sylacauga
# Processing Record 4 of Set 6 | pau brasil
# Processing Record 5 of Set 6 | acajutla
# Processing Record 6 of Set 6 | feijo
# Processing Record 7 of Set 6 | derzhavinsk
# Processing Record 8 of Set 6 | kalmunai
# Processing Record 9 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 10 of Set 6 | semnan
# Processing Record 11 of Set 6 | arraial do cabo
# Processing Record 12 of Set 6 | oktyabrskiy
# Processing Record 13 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 14 of Set 6 | sakakah
# Processing Record 15 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 16 of Set 6 | port lincoln
# Processing Record 17 of Set 6 | hamilton
# Processing Record 18 of Set 6 | klaksvik
# Processing Record 19 of Set 6 | vryburg
# Processing Record 20 of Set 6 | coihaique
# Processing Record 21 of Set 6 | moose factory
# Processing Record 22 of Set 6 | pangnirtung
# Processing Record 23 of Set 6 | iwanai
# Processing Record 24 of Set 6 | jablah
# Processing Record 25 of Set 6 | shenjiamen
# Processing Record 26 of Set 6 | san quintin
# Processing Record 27 of Set 6 | alice springs
# Processing Record 28 of Set 6 | kiama
# Processing Record 29 of Set 6 | tadine
# Processing Record 30 of Set 6 | hofn
# Processing Record 31 of Set 6 | wukari
# Processing Record 32 of Set 6 | pierre
# Processing Record 33 of Set 6 | touros
# Processing Record 34 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 35 of Set 6 | sambava
# Processing Record 36 of Set 6 | saint-francois
# Processing Record 37 of Set 6 | kurilsk
# Processing Record 38 of Set 6 | tezu
# Processing Record 39 of Set 6 | chuy
# Processing Record 40 of Set 6 | okhotsk
# Processing Record 41 of Set 6 | grand gaube
# Processing Record 42 of Set 6 | regeneracao
# Processing Record 43 of Set 6 | chitungwiza
# Processing Record 44 of Set 6 | beyneu
# Processing Record 45 of Set 6 | kidal
# Processing Record 46 of Set 6 | tucuman
# Processing Record 47 of Set 6 | synya
# Processing Record 48 of Set 6 | lorengau
# Processing Record 49 of Set 6 | san andres
# Processing Record 50 of Set 6 | cabedelo
# Processing Record 1 of Set 7 | comodoro rivadavia
# Processing Record 2 of Set 7 | huarmey
# Processing Record 3 of Set 7 | bairiki
# Processing Record 4 of Set 7 | sehithwa
# Processing Record 5 of Set 7 | bambanglipuro
# Processing Record 6 of Set 7 | cedar city
# Processing Record 7 of Set 7 | faanui
# Processing Record 8 of Set 7 | beringovskiy
# Processing Record 9 of Set 7 | camacupa
# Processing Record 10 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 7 | rocha
# Processing Record 12 of Set 7 | olafsvik
# Processing Record 13 of Set 7 | tecoanapa
# Processing Record 14 of Set 7 | izhma
# Processing Record 15 of Set 7 | port-de-paix
# City not found. Skipping...
# Processing Record 16 of Set 7 | lamu
# Processing Record 17 of Set 7 | kailua
# Processing Record 18 of Set 7 | bathsheba
# Processing Record 19 of Set 7 | mangan
# Processing Record 20 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 21 of Set 7 | pula
# Processing Record 22 of Set 7 | noumea
# Processing Record 23 of Set 7 | dong xoai
# Processing Record 24 of Set 7 | paamiut
# Processing Record 25 of Set 7 | abu samrah
# Processing Record 26 of Set 7 | port augusta
# Processing Record 27 of Set 7 | wawa
# Processing Record 28 of Set 7 | puerto carreno
# Processing Record 29 of Set 7 | saint george
# Processing Record 30 of Set 7 | jorpeland
# Processing Record 31 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 7 | tsybli
# Processing Record 33 of Set 7 | necochea
# Processing Record 34 of Set 7 | saldanha
# Processing Record 35 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 7 | hualmay
# Processing Record 37 of Set 7 | chara
# Processing Record 38 of Set 7 | ostersund
# Processing Record 39 of Set 7 | zhangjiakou
# Processing Record 40 of Set 7 | constitucion
# Processing Record 41 of Set 7 | mikkeli
# Processing Record 42 of Set 7 | batsfjord
# Processing Record 43 of Set 7 | walvis bay
# Processing Record 44 of Set 7 | geraldton
# Processing Record 45 of Set 7 | yicheng
# Processing Record 46 of Set 7 | coquimbo
# Processing Record 47 of Set 7 | altus
# Processing Record 48 of Set 7 | kutum
# Processing Record 49 of Set 7 | borda da mata
# Processing Record 50 of Set 7 | murgab
# Processing Record 1 of Set 8 | sangar
# Processing Record 2 of Set 8 | lebu
# Processing Record 3 of Set 8 | nioro
# Processing Record 4 of Set 8 | garwolin
# Processing Record 5 of Set 8 | betul
# Processing Record 6 of Set 8 | kilinochchi
# Processing Record 7 of Set 8 | villamontes
# Processing Record 8 of Set 8 | nador
# Processing Record 9 of Set 8 | namibe
# Processing Record 10 of Set 8 | phan thiet
# Processing Record 11 of Set 8 | aban
# Processing Record 12 of Set 8 | pennagaram
# Processing Record 13 of Set 8 | exeter
# Processing Record 14 of Set 8 | muros
# Processing Record 15 of Set 8 | cairns
# Processing Record 16 of Set 8 | opuwo
# Processing Record 17 of Set 8 | rafaela
# Processing Record 18 of Set 8 | deputatskiy
# Processing Record 19 of Set 8 | rawson
# Processing Record 20 of Set 8 | lagunas
# Processing Record 21 of Set 8 | atherton
# Processing Record 22 of Set 8 | latung
# Processing Record 23 of Set 8 | poshekhonye
# Processing Record 24 of Set 8 | eregli
# Processing Record 25 of Set 8 | kasama
# Processing Record 26 of Set 8 | nanakuli
# Processing Record 27 of Set 8 | oyama
# Processing Record 28 of Set 8 | airai
# Processing Record 29 of Set 8 | russell
# Processing Record 30 of Set 8 | la palma
# Processing Record 31 of Set 8 | bamako
# Processing Record 32 of Set 8 | west lafayette
# Processing Record 33 of Set 8 | yining
# Processing Record 34 of Set 8 | havre-saint-pierre
# Processing Record 35 of Set 8 | itarema
# Processing Record 36 of Set 8 | hay river
# Processing Record 37 of Set 8 | san cristobal
# Processing Record 38 of Set 8 | saint-augustin
# Processing Record 39 of Set 8 | manggar
# Processing Record 40 of Set 8 | paragould
# Processing Record 41 of Set 8 | sarab
# Processing Record 42 of Set 8 | asfi
# Processing Record 43 of Set 8 | kloulklubed
# Processing Record 44 of Set 8 | calama
# Processing Record 45 of Set 8 | roebourne
# Processing Record 46 of Set 8 | nikolskoye
# Processing Record 47 of Set 8 | dingle
# Processing Record 48 of Set 8 | chabahar
# Processing Record 49 of Set 8 | abu kamal
# Processing Record 50 of Set 8 | alyangula
# Processing Record 1 of Set 9 | labuhan
# Processing Record 2 of Set 9 | asau
# Processing Record 3 of Set 9 | itoman
# Processing Record 4 of Set 9 | turukhansk
# Processing Record 5 of Set 9 | saskylakh
# Processing Record 6 of Set 9 | lavrentiya
# Processing Record 7 of Set 9 | domoni
# Processing Record 8 of Set 9 | linhares
# Processing Record 9 of Set 9 | grand-santi
# Processing Record 10 of Set 9 | tunduru
# City not found. Skipping...
# Processing Record 11 of Set 9 | mogadishu
# Processing Record 12 of Set 9 | tumut
# Processing Record 13 of Set 9 | tsumeb
# Processing Record 14 of Set 9 | nha trang
# Processing Record 15 of Set 9 | markala
# Processing Record 16 of Set 9 | husavik
# Processing Record 17 of Set 9 | dickinson
# Processing Record 18 of Set 9 | shasta lake
# Processing Record 19 of Set 9 | trunovskoye
# Processing Record 20 of Set 9 | buala
# Processing Record 21 of Set 9 | bilibino
# Processing Record 22 of Set 9 | umm lajj
# Processing Record 23 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 9 | zheshart
# Processing Record 25 of Set 9 | nuevo progreso
# Processing Record 26 of Set 9 | verkhnyaya inta
# Processing Record 27 of Set 9 | palmer
# Processing Record 28 of Set 9 | egvekinot
# Processing Record 29 of Set 9 | rio gallegos
# Processing Record 30 of Set 9 | tynda
# Processing Record 31 of Set 9 | tabory
# Processing Record 32 of Set 9 | tyukalinsk
# Processing Record 33 of Set 9 | korla
# Processing Record 34 of Set 9 | yungkang
# City not found. Skipping...
# Processing Record 35 of Set 9 | kunda
# Processing Record 36 of Set 9 | ereymentau
# Processing Record 37 of Set 9 | tucupita
# Processing Record 38 of Set 9 | bakel
# Processing Record 39 of Set 9 | marsa matruh
# Processing Record 40 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 9 | iqaluit
# Processing Record 42 of Set 9 | ishigaki
# Processing Record 43 of Set 9 | orlik
# Processing Record 44 of Set 9 | mayo
# Processing Record 45 of Set 9 | ust-maya
# Processing Record 46 of Set 9 | charters towers
# Processing Record 47 of Set 9 | ulladulla
# Processing Record 48 of Set 9 | tomatlan
# Processing Record 49 of Set 9 | dharchula
# Processing Record 50 of Set 9 | payo
# Processing Record 1 of Set 10 | evensk
# Processing Record 2 of Set 10 | molde
# Processing Record 3 of Set 10 | marzuq
# Processing Record 4 of Set 10 | yulara
# Processing Record 5 of Set 10 | goundi
# Processing Record 6 of Set 10 | oksfjord
# Processing Record 7 of Set 10 | olga
# Processing Record 8 of Set 10 | sungaipenuh
# Processing Record 9 of Set 10 | bukachacha
# Processing Record 10 of Set 10 | bud
# Processing Record 11 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 10 | maamba
# Processing Record 13 of Set 10 | tingo maria
# Processing Record 14 of Set 10 | tarata
# Processing Record 15 of Set 10 | severo-yeniseyskiy
# Processing Record 16 of Set 10 | bandar
# Processing Record 17 of Set 10 | kamogawa
# Processing Record 18 of Set 10 | omboue
# Processing Record 19 of Set 10 | adrar
# Processing Record 20 of Set 10 | la peca
# Processing Record 21 of Set 10 | cidreira
# Processing Record 22 of Set 10 | coulihaut
# City not found. Skipping...
# Processing Record 23 of Set 10 | raudeberg
# Processing Record 24 of Set 10 | otradnoye
# Processing Record 25 of Set 10 | seymchan
# Processing Record 26 of Set 10 | shchelkun
# Processing Record 27 of Set 10 | waddan
# Processing Record 28 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 29 of Set 10 | los llanos de aridane
# Processing Record 30 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 10 | whitecourt
# Processing Record 32 of Set 10 | ban nahin
# Processing Record 33 of Set 10 | cayenne
# Processing Record 34 of Set 10 | kruisfontein
# Processing Record 35 of Set 10 | westport
# Processing Record 36 of Set 10 | kununurra
# Processing Record 37 of Set 10 | saint anthony
# Processing Record 38 of Set 10 | minab
# Processing Record 39 of Set 10 | faya
# Processing Record 40 of Set 10 | la paz
# Processing Record 41 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 42 of Set 10 | nichinan
# Processing Record 43 of Set 10 | hit
# Processing Record 44 of Set 10 | port hedland
# Processing Record 45 of Set 10 | nizamabad
# Processing Record 46 of Set 10 | pitkyaranta
# Processing Record 47 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 48 of Set 10 | auki
# Processing Record 49 of Set 10 | peniche
# Processing Record 50 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 1 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 11 | bo rai
# Processing Record 3 of Set 11 | chulucanas
# Processing Record 4 of Set 11 | vila
# Processing Record 5 of Set 11 | petauke
# Processing Record 6 of Set 11 | svetlyy
# Processing Record 7 of Set 11 | cabo san lucas
# Processing Record 8 of Set 11 | petershagen
# Processing Record 9 of Set 11 | puerto cabezas
# Processing Record 10 of Set 11 | kumluca
# Processing Record 11 of Set 11 | mastic beach
# Processing Record 12 of Set 11 | am timan
# Processing Record 13 of Set 11 | sola
# Processing Record 14 of Set 11 | vanimo
# Processing Record 15 of Set 11 | barra patuca
# Processing Record 16 of Set 11 | port-gentil
# Processing Record 17 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 18 of Set 11 | taoudenni
# Processing Record 19 of Set 11 | baykit
# Processing Record 20 of Set 11 | garsten
# Processing Record 21 of Set 11 | khorixas
# Processing Record 22 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 11 | hovd
# Processing Record 25 of Set 11 | kantang
# Processing Record 26 of Set 11 | madras
# Processing Record 27 of Set 11 | mineros
# Processing Record 28 of Set 11 | paralimni
# Processing Record 29 of Set 11 | siyabuswa
# Processing Record 30 of Set 11 | tautira
# Processing Record 31 of Set 11 | lodja
# Processing Record 32 of Set 11 | tura
# Processing Record 33 of Set 11 | skibbereen
# Processing Record 34 of Set 11 | karaton
# Processing Record 35 of Set 11 | broken hill
# Processing Record 36 of Set 11 | chifeng
# Processing Record 37 of Set 11 | caxias
# Processing Record 38 of Set 11 | kota belud
# Processing Record 39 of Set 11 | henties bay
# Processing Record 40 of Set 11 | maniitsoq
# Processing Record 41 of Set 11 | kwinana
# Processing Record 42 of Set 11 | cortona
# Processing Record 43 of Set 11 | maxixe
# Processing Record 44 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 11 | warrington
# Processing Record 46 of Set 11 | pamanukan
# Processing Record 47 of Set 11 | naliya
# Processing Record 48 of Set 11 | beloha
# Processing Record 49 of Set 11 | sarh
# Processing Record 50 of Set 11 | morgan city
# Processing Record 1 of Set 12 | griffith
# Processing Record 2 of Set 12 | lavumisa
# Processing Record 3 of Set 12 | moerai
# Processing Record 4 of Set 12 | pljevlja
# Processing Record 5 of Set 12 | teya
# Processing Record 6 of Set 12 | slave lake
# Processing Record 7 of Set 12 | gidam
# Processing Record 8 of Set 12 | warrnambool
# Processing Record 9 of Set 12 | khasan
# Processing Record 10 of Set 12 | isangel
# Processing Record 11 of Set 12 | pangody
# Processing Record 12 of Set 12 | matara
# Processing Record 13 of Set 12 | luena
# Processing Record 14 of Set 12 | namatanai
# Processing Record 15 of Set 12 | krasnyy chikoy
# Processing Record 16 of Set 12 | kang
# Processing Record 17 of Set 12 | torbay
# Processing Record 18 of Set 12 | gisborne
# Processing Record 19 of Set 12 | alice town
# Processing Record 20 of Set 12 | maldonado
# Processing Record 21 of Set 12 | richards bay
# Processing Record 22 of Set 12 | kholm
# Processing Record 23 of Set 12 | billings
# Processing Record 24 of Set 12 | plettenberg bay
# Processing Record 25 of Set 12 | oranjemund
# Processing Record 26 of Set 12 | honningsvag
# Processing Record 27 of Set 12 | sobolevo
# Processing Record 28 of Set 12 | shirokiy
# Processing Record 29 of Set 12 | fairbanks
# Processing Record 30 of Set 12 | les cayes
# Processing Record 31 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 32 of Set 12 | karratha
# Processing Record 33 of Set 12 | guasdualito
# Processing Record 34 of Set 12 | luanda
# Processing Record 35 of Set 12 | misratah
# Processing Record 36 of Set 12 | westerland
# Processing Record 37 of Set 12 | tulun
# Processing Record 38 of Set 12 | gatesville
# Processing Record 39 of Set 12 | shelburne
# Processing Record 40 of Set 12 | hukuntsi
# Processing Record 41 of Set 12 | svetlogorsk
# Processing Record 42 of Set 12 | vaitape
# Processing Record 43 of Set 12 | chelbasskaya
# Processing Record 44 of Set 12 | dali
# Processing Record 45 of Set 12 | hasaki
# Processing Record 46 of Set 12 | charlestown
# Processing Record 47 of Set 12 | galesong
# Processing Record 48 of Set 12 | upernavik
# Processing Record 49 of Set 12 | maputo
# Processing Record 50 of Set 12 | antofagasta
# Processing Record 1 of Set 13 | bastia
# Processing Record 2 of Set 13 | ashqelon
# Processing Record 3 of Set 13 | zlobin
# Processing Record 4 of Set 13 | huilong
# Processing Record 5 of Set 13 | kirakira
# Processing Record 6 of Set 13 | twentynine palms
# Processing Record 7 of Set 13 | harrisonburg
# Processing Record 8 of Set 13 | trairi
# Processing Record 9 of Set 13 | canto do buriti
# Processing Record 10 of Set 13 | tazmalt
# Processing Record 11 of Set 13 | port hawkesbury
# Processing Record 12 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 13 | puerto escondido
# Processing Record 14 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 15 of Set 13 | talnakh
# Processing Record 16 of Set 13 | copiapo
# Processing Record 17 of Set 13 | dalmatovo
# Processing Record 18 of Set 13 | kashi
# Processing Record 19 of Set 13 | berlevag
# Processing Record 20 of Set 13 | aksarka
# Processing Record 21 of Set 13 | bartica
# Processing Record 22 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 13 | zelenoborsk
# Processing Record 24 of Set 13 | cabra
# Processing Record 25 of Set 13 | vrangel
# Processing Record 26 of Set 13 | ca mau
# Processing Record 27 of Set 13 | novoseleznevo
# Processing Record 28 of Set 13 | zigong
# Processing Record 29 of Set 13 | beian
# Processing Record 30 of Set 13 | noyabrsk
# Processing Record 31 of Set 13 | maymanak
# City not found. Skipping...
# Processing Record 32 of Set 13 | alberton
# Processing Record 33 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 34 of Set 13 | vuktyl
# Processing Record 35 of Set 13 | kampot
# Processing Record 36 of Set 13 | pathein
# Processing Record 37 of Set 13 | grindavik
# Processing Record 38 of Set 13 | tabas
# Processing Record 39 of Set 13 | nieuw amsterdam
# Processing Record 40 of Set 13 | kasamwa
# Processing Record 41 of Set 13 | buchanan
# Processing Record 42 of Set 13 | solnechnyy
# Processing Record 43 of Set 13 | boffa
# Processing Record 44 of Set 13 | clyde river
# Processing Record 45 of Set 13 | kollam
# Processing Record 46 of Set 13 | susanville
# Processing Record 47 of Set 13 | ivankiv
# Processing Record 48 of Set 13 | letlhakane
# Processing Record 49 of Set 13 | kabalo
# Processing Record 50 of Set 13 | meulaboh
# Processing Record 1 of Set 14 | dalbandin
# Processing Record 2 of Set 14 | lucapa
# Processing Record 3 of Set 14 | sochi
# Processing Record 4 of Set 14 | tashtyp
# Processing Record 5 of Set 14 | dunedin
# Processing Record 6 of Set 14 | luang prabang
# Processing Record 7 of Set 14 | novomikhaylovskiy
# Processing Record 8 of Set 14 | leshukonskoye
# Processing Record 9 of Set 14 | moroni
# Processing Record 10 of Set 14 | antalaha
# Processing Record 11 of Set 14 | saint-die
# City not found. Skipping...
# Processing Record 12 of Set 14 | stornoway
# Processing Record 13 of Set 14 | general roca
# Processing Record 14 of Set 14 | filimonovo
# Processing Record 15 of Set 14 | yuncheng
# Processing Record 16 of Set 14 | suhbaatar
# Processing Record 17 of Set 14 | camopi
# Processing Record 18 of Set 14 | lusambo
# Processing Record 19 of Set 14 | carutapera
# Processing Record 20 of Set 14 | ust-koksa
# Processing Record 21 of Set 14 | baffa
# Processing Record 22 of Set 14 | tessalit
# Processing Record 23 of Set 14 | rosarito
# Processing Record 24 of Set 14 | venice
# Processing Record 25 of Set 14 | nisia floresta
# Processing Record 26 of Set 14 | oliveira dos brejinhos
# Processing Record 27 of Set 14 | gat
# Processing Record 28 of Set 14 | tansen
# Processing Record 29 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 14 | el badari
# City not found. Skipping...
# Processing Record 31 of Set 14 | sassandra
# Processing Record 32 of Set 14 | along
# Processing Record 33 of Set 14 | sug-aksy
# City not found. Skipping...
# Processing Record 34 of Set 14 | smithers
# Processing Record 35 of Set 14 | little rock
# Processing Record 36 of Set 14 | shaunavon
# Processing Record 37 of Set 14 | paita
# Processing Record 38 of Set 14 | milas
# Processing Record 39 of Set 14 | vila franca do campo
# Processing Record 40 of Set 14 | kutno
# Processing Record 41 of Set 14 | gillette
# Processing Record 42 of Set 14 | vicuna
# Processing Record 43 of Set 14 | alamos
# Processing Record 44 of Set 14 | cheyenne
# Processing Record 45 of Set 14 | jelenia gora
# Processing Record 46 of Set 14 | polyarnyy
# Processing Record 47 of Set 14 | yokadouma
# Processing Record 48 of Set 14 | jaguarao
# Processing Record 49 of Set 14 | miandrivazo
# Processing Record 50 of Set 14 | zapolyarnyy
# Processing Record 1 of Set 15 | mayor pablo lagerenza
# Processing Record 2 of Set 15 | dakar
# Processing Record 3 of Set 15 | san jeronimo
# Processing Record 4 of Set 15 | longavi
# Processing Record 5 of Set 15 | qandahar
# City not found. Skipping...
# Processing Record 6 of Set 15 | palencia
# Processing Record 7 of Set 15 | ebano
# City not found. Skipping...
# Processing Record 8 of Set 15 | mitu
# Processing Record 9 of Set 15 | bacau
# Processing Record 10 of Set 15 | kochki
# Processing Record 11 of Set 15 | luba
# Processing Record 12 of Set 15 | reefton
# City not found. Skipping...
# Processing Record 13 of Set 15 | waingapu
# Processing Record 14 of Set 15 | kencong
# Processing Record 15 of Set 15 | dawson creek
# Processing Record 16 of Set 15 | rafraf
# Processing Record 17 of Set 15 | arnprior
# Processing Record 18 of Set 15 | kuminskiy
# Processing Record 19 of Set 15 | crotone
# Processing Record 20 of Set 15 | te anau
# Processing Record 21 of Set 15 | nueva gerona
# Processing Record 22 of Set 15 | puerto lempira
# Processing Record 23 of Set 15 | novyy urengoy
# Processing Record 24 of Set 15 | ye
# City not found. Skipping...
# Processing Record 25 of Set 15 | belle glade
# Processing Record 26 of Set 15 | maba
# Processing Record 27 of Set 15 | sawankhalok
# Processing Record 28 of Set 15 | pasighat
# Processing Record 29 of Set 15 | shirokovskiy
# Processing Record 30 of Set 15 | araouane
# Processing Record 31 of Set 15 | anadyr
# Processing Record 32 of Set 15 | port keats
# Processing Record 33 of Set 15 | pauini
# Processing Record 34 of Set 15 | kindu
# Processing Record 35 of Set 15 | clarence town
# Processing Record 36 of Set 15 | labytnangi
# Processing Record 37 of Set 15 | alzamay
# Processing Record 38 of Set 15 | nenjiang
# Processing Record 39 of Set 15 | mackay
# Processing Record 40 of Set 15 | xiongzhou
# Processing Record 41 of Set 15 | hobyo
# Processing Record 42 of Set 15 | havelock
# Processing Record 43 of Set 15 | vestmannaeyjar
# Processing Record 44 of Set 15 | aripuana
# Processing Record 45 of Set 15 | kattivakkam
# Processing Record 46 of Set 15 | mitsamiouli
# Processing Record 47 of Set 15 | batticaloa
# Processing Record 48 of Set 15 | teguldet
# Processing Record 49 of Set 15 | bermejo
# Processing Record 50 of Set 15 | varhaug
# Processing Record 1 of Set 16 | salinopolis
# Processing Record 2 of Set 16 | roma
# Processing Record 3 of Set 16 | nishihara
# Processing Record 4 of Set 16 | leningradskiy
# Processing Record 5 of Set 16 | kasempa
# Processing Record 6 of Set 16 | uga
# Processing Record 7 of Set 16 | socorro
# Processing Record 8 of Set 16 | carbonia
# Processing Record 9 of Set 16 | najran
# Processing Record 10 of Set 16 | mahibadhoo
# Processing Record 11 of Set 16 | awjilah
# Processing Record 12 of Set 16 | pacific grove
# Processing Record 13 of Set 16 | laguna de perlas
# Processing Record 14 of Set 16 | aykhal
# Processing Record 15 of Set 16 | hendek
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 701

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_df = pd.DataFrame(city_data)
city_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas      CL -53.1500  -70.9167     46.11        81          99
# 1  Ribeira Grande      PT  38.5167  -28.7000     59.83        75          14
# 2           Vardo      NO  70.3705   31.1107     22.51        80          56
# 3   Qasigiannguit      GL  68.8193  -51.1922     -0.44        93         100
# 4          Ossora      RU  59.2353  163.0719     19.96        94         100
#
#    Wind Speed Current Description
# 0       21.45          light rain
# 1       14.32          few clouds
# 2        8.79       broken clouds
# 3       12.95     overcast clouds
# 4       13.98                snow

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_df.to_csv(output_data_file, index_label="City_ID")
